# %%
import os, sys, argparse
import pandas as pd
import backtrader as bt
from strategies.GoldenCross import GoldenCross
from strategies.BuyHold import BuyHold



cerebro = bt.Cerebro()
#SET CASH TO 100000
cerebro.broker.set_cash(100000)
spy_prices = pd.read_csv('data/SPY.csv', index_col = "Date", parse_dates = True)

#Possible to integrate Yahoo Finance API at this point

feed = bt.feeds.PandasData(dataname = spy_prices)
cerebro.adddata(feed)
cerebro.addstrategy(GoldenCross)
print("Starting Portfolio Value: %.2f" % cerebro.broker.getvalue())
cerebro.run()
print("Ending Portfolio Value: %.2f" % cerebro.broker.getvalue())
cerebro.plot()
# Out:
# Starting Portfolio Value: 100000.00
# BUY 998 shares of SPY at 95.110001
# SELL 998 shares of SPY at 110.029999
# BUY 930 shares of SPY at 117.279999
# SELL 930 shares of SPY at 125.690002
# BUY 898 shares of SPY at 130.41000400000001
# SELL 898 shares of SPY at 148.130005
# BUY 1486 shares of SPY at 89.349998
# SELL 1486 shares of SPY at 102.870003
# BUY 1276 shares of SPY at 118.349998
# SELL 1276 shares of SPY at 118.120003
# BUY 1151 shares of SPY at 131.320007
# SELL 1151 shares of SPY at 199.279999
# BUY 1089 shares of SPY at 204.860001
# SELL 1089 shares of SPY at 192.110001
# BUY 1025 shares of SPY at 208.610001
# SELL 1025 shares of SPY at 263.570007
# BUY 933 shares of SPY at 285.829987
# Ending Portfolio Value: 305848.63
# <img src="data:image/png;base64,..." width="927.4999861791732">
# [[<Figure size 640x480 with 5 Axes>]]
